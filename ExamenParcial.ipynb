# %% [markdown]
# # Parte 1 Fundamentos de Ruby
# (3 puntos) implementar un comando grep simplificado, que admita la búsqueda de cadenas fijas. Busca en archivos líneas que coincidan con una cadena de búsqueda y devuelva todas las líneas coincidentes.

# %%
def grep_simplificado(string, texto)
  matches = []  # guardamos los matches encontrados
  start_index = 0  # Inicializamos el índice para la búsqueda 
  while (index = texto.index(string, start_index))
    matches << texto[index, string.length] # guardamos 
    start_index = index + 1  # Actualizamos el índice de inicio 
  end
  matches  # Devolvemos la lista de matches encontrados
end
# Out:
# :grep_simplificado

# %%
string = "hola"
texto = "hola como estan, hola jaja, hola y tu?"
matches = grep_simplificado(string, texto)
puts "Matches encontrados: #{matches}"  # Imprime mis maches
# Out:
# Matches encontrados: ["hola", "hola", "hola"]

# %% [markdown]
# (3 puntos) El principio abierto-cerrado dice que una clase debe estar abierta a la extensión, pero cerrada a la modificación. Una extensión en el caso de Ruby sería agregar variables y métodos de instancia y una modificación sería modificar o eliminar variables o métodos de instancia existentes. El principio abierto-cerrado se escribió principalmente para abordar problemas con el software compilado escrito en lenguajes de programación que son menos expresivos que Ruby. En Ruby, prácticamente todas las clases están abiertas tanto para extensión como para modificación.

# %%
class OpenClosed
    def self.meths(m)
        m.instance_methods + m.private_instance_methods
    end
end
# Out:
# :meths

# %% [markdown]
# (2 puntos) Responde las siguientes preguntas (2 preguntas)
# **2. ¿Cuándo es una mala idea implementar una abstracción mediante metaprogramación?**
# Es una malaidea usar metaprogramación para abstracciones si afecta la claridad y mantenibilidad del código sin beneficios signficativos.
# **3. ¿Siempre es malo utilizar abstracciones en el código de prueba?**
# No, las abstracciones en el código de prueba no son siempre malas pero deben ser utilzadas con cuidado y de manera apropiada para el contexto y objetivo delas pruebas.
# **5. ¿Cuál es el requisito previo más importante antes de comenzar una refactorización?**
# El requisito previo más importante antes de comenzar una refactorización es tener una suite de pruebas sólida y complta que cubra adecuadamente el código existente.

# %% [markdown]
# # Parte 2: Introducción a Rails (4 puntos)
# Para crear una aplicación Rails, usaremos el comando rails new <app_name>- Escribe lo siguiente en el símbolo del sistema e ingresa:
# $rails new todo_app
# Esta es la salida que tendremos:
# ademas que se creo todo esto:

# %% [markdown]
# ![image.png](attachment:935e5f02-0642-46f2-a57d-2dffc3512222.png)

# %% [markdown]
# Ademas que se creo todo esto:
# ![image.png](attachment:8a6acd25-0d89-473d-bd55-e6c858084ab3.png)

# %% [markdown]
# Ahora cambie el directorio a "todo_app", luego escriba e ingrese lo siguiente en el símbolo del sistema:
# rails generate scaffold todo description:string
# Tendremos esta salida:
# ![image.png](attachment:61ba4bfd-8ebd-4d36-8718-9c42fd0c5206.png)
# ## Base de datos
# Aún dentro de la raíz del directorio "todo_app", escriba e ingresa lo siguiente en el símbolo del sistema (recuerda la versión de tu trabajo):
# bundle exec rake db:migrate
# Lamigracion deberia verse de esta manera:
# ![image.png](attachment:e73fecb8-0863-4fa4-9c4b-abf6891e4610.png)
# Abre db/seeds.rb en un editor de texto de tu elección, luego pega las dos líneas siguientes en la parte inferior del archivo, debajo de los comentarios:
# Todo.create(description: "Hello CC3S2- Kids")
# Todo.create(description: " Do the assignments kid ")
# nos movemos:
# ![image.png](attachment:3c47bfb1-f2c9-44b6-9b51-b1b7649282df.png)
# Agregamos los descrito:
# ![image.png](attachment:257b372e-57d7-4ca1-9743-6c9d9b5ca5b9.png)
# Iniciamos el servidor:
# ![image.png](attachment:247c51f3-b4e1-4698-9512-3fc770c75050.png)
# Buscamos la pagina en donde nos dice, podremos notar que nos muestra la plantilla por defecto de rails:
# ![image.png](attachment:187431c0-5930-4ee4-ace9-55b0963a290d.png)
# Corremos el comando scaffold:
# ![image.png](attachment:a53e5db2-99c3-4e99-827e-89b871c77cbe.png)
# y volvemos a migrar la BD
# ![image.png](attachment:bd496bad-3579-483b-bf1d-73de96c5b536.png)
# ## Más migraciones
# **La primera migración nos permitió crear la base de datos. Digamos que el cliente quiere que cada "tareas pendientes" tenga una fecha de vencimiento asociada. ¿Cómo hacemos que eso suceda?**
# Lo que s epodria acer es Generar una migracion pero para agregar una columna de vencimiento, podriamos llamarla "due_date", aplicamos la migracion y en el modelo todo.rb agregar una linea que valide si "due_date" esta vencida o no, y con eso lo acosiamos, por ultimo tmb le actualizaria las vistas y controladores para permitir al usuario que ingrese su fechas de las tareas pendientes que menciona.
# **¿Qué archivos nuevos o cambios en los archivos existentes han ocurrido?.**
# Los cambios se pueden notar en el comando de la imagen de scaffold:
# ![image.png](attachment:86635da1-9f56-44ce-8b27-f001da583b1a.png)
# ## Nuevas Rutas
# 1. Agrega una ruta en config/routes.rb y asígnela a una acción del controlador. (Coloca esta línea dentro del cuerpo de route.draw).
# get ’/hello’, to: ’todos#hello’
# Asi como se muestra en la imagen:
# ![image.png](attachment:f598d1a5-3370-4060-ba44-79d2346667fe.png)
# 2. Añade una nueva vista correspondiente a la ruta. Si alguien navega a la página "hello" de tu aplicación (es decir, "http://localhost:3000/hello/"), se mostrará una página web.
# · Crea un archivo en el directorio app/views/todos llamado hello.html.erb.
# ![image.png](attachment:a122f1a8-7eca-4d21-8963-56d2267ec6f0.png)
# · Puedes ingresar cualquier HTML que desees para mostrar tu página web, pero por ahora solo puedes escribir hola.
# ![image.png](attachment:8dee42fb-4b26-4017-8703-9a40e656aa04.png)
# · Agrega el siguiente método a app/controllers/todos_controller.rb.
# ![image.png](attachment:c156ec18-df0d-4a2b-a045-a720c476f58a.png)
# Agregamos lo mostrado en el word:
# ![image.png](attachment:2b2dde19-e603-401a-8260-bfdae5b3dccc.png)
# Comprobamos buscando la pagina:
# ![image.png](attachment:01e4b0ac-2ea5-48ad-a6b7-b14456ace134.png)

# %% [markdown]
# # Parte 3: Ruby on Rails (8 puntos)
# Clona el repositorio
# ![image.png](attachment:a5beaace-1d5c-4f37-a781-cada10a2e2f2.png)
# ahora cambiamos a la version 2.6.6 de ruby y instalamos las gemas especificadas con bundle install
# ![image.png](attachment:4812971f-f420-4308-bafa-1679708f4858.png)
# ![image.png](attachment:ae65f208-1b7d-4cb8-ab8c-afdc7d3ec1b5.png)
# y corremos el servidor:
# ![image.png](attachment:61b5012b-98ca-43b1-9a4b-ec5fc2e9f70e.png)
# nos fijamos en la pagina con su respectivo puerto:
# ![image.png](attachment:b9e697eb-bd52-452c-93df-5df09157fe46.png)
# Preguntas (1 punto):
# **¿Cuál es el objetivo de ejecutar bundle install?**
# Intalar todas la gemas que estan el arvhivo Gemfile y genear tmabien un Gemfile.lock
# **¿Por qué es una buena práctica especificar –without production al ejecutarlo en su computadora de desarrollo?**
# Es que asi mantenemos limpio nuesto entorno de desarrollo  reduciiendo posibilidades de compatibilidad, porque evitamos la instalacion de las gemas que son solo de producción
# **(Para la mayoría de las aplicaciones Rails, también tendrías que crear y inicializar la base de datos de desarrollo, pero al igual que la aplicación Sinatra, esta aplicación no utiliza ninguna base de datos)**
# Es que no esnecsario debido a que sinatra no utiliza base de datos, pero la mayoria tienen ese paso en comun
# ******************
# Juega para convencerte de que funciona igual que la versión de Sinatra.
# jaja gane:
# ![image.png](attachment:5ada72b5-213e-4067-b96b-ed62b01c77e0.png)
# perdi:
# ![image.png](attachment:af05293a-77a3-40c4-9a7c-bf8949e907ab.png)
# el servidor muestra:
# ![image.png](attachment:5247124e-6fa3-42da-8495-b7eb43a3f1ec.png)
# Preguntas (3 puntos):
# **¿En qué parte de la estructura del directorio de la aplicación Rails está el código correspondiente al modelo WordGuesserGame?**
#
# Sen encuentra en el directorio app/model
# ![image.png](attachment:d329e871-5c6e-43aa-9e7f-caee53473f6b.png)
# ![image.png](attachment:e332f34d-db98-494a-bea3-73c59191493a.png)
# **¿En qué archivo está el código que más se corresponde con la lógica del archivo app.rb de las aplicaciones Sinatra que maneja las acciones entrantes del usuario?**
#
# Eso esta en el archivo controllers  app/controllers/gmaes_controller.rb
# ![image.png](attachment:81b95adf-fd25-4101-82a2-42db1a4c3af4.png)
# ![image.png](attachment:3083ef11-f692-4b32-b3fb-41b6cd60b035.png)
# **¿Qué clase contiene ese código?**
#
# contiene  Gamecontroller
# ![image.png](attachment:0c8f9202-b7bf-4223-8344-533bdbbad2c9.png)
# **¿De qué otra clase (que es parte del framework Rails) hereda esa clase?**
#
# En la imagen anterior se puede notar que es de < ApplicationController
# ![image.png](attachment:d33eca00-abdf-40c7-a736-137c072117ef.png)
# **¿En qué directorio está el código correspondiente a las vistas de la aplicación Sinatra (new.erb, show.erb, etc.)?**
#
# se encuentra en hw-rails-wordguesser/app/views/game
# ![image.png](attachment:2dc25f6c-34f1-4306-83e5-d3163977c167.png)
# **Los sufijos de nombre de archivo para estas vistas son diferentes en Rails que en la aplicación Sinatra. ¿Qué información proporciona el sufijo situado más a la derecha del nombre del archivo (por ejemplo: en foobar.abc.xyz, el sufijo .xyz) sobre el contenido del archivo?**
#
# bueno en Rails el sufijo más a la derecha nos da el formato de la repsuesta, eso se puede notar en la imagen anterior
# **¿Qué información te brinda el otro sufijo sobre lo que se le pide a Rails que haga con el archivo?**
#
# este nos indica el tipode plantilla y tambien como procesar el archivo, tambien se nota en la imagen que se menciono
# **¿En qué archivo está la información de la aplicación Rails que asigna rutas (por ejemplo, GET/new) a las acciones del controlador?**
#
# eso esta confg/routes.rb aqui se muestra:
# ![image.png](attachment:dee1b0e2-80b7-4d7d-a5b2-a53d98fdd231.png)
# **¿Cuál es el papel de la opción :as => 'name' en las declaraciones de ruta de config/routes.rb?**
#
# En la imagen anterior se puede ver varios as => 'name' que señala, esto asigna un nombre  ala ruta para hacer mas facil la referncia cuando codeamos, creando metodos de ruta con ese name que se señala.
